# %% [markdown]
# ## 1. Explore the data
# Loading the dataset and displaying basic information.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = 'StudentsPerformance.csv'
data = pd.read_csv(file)
data.head(5)
# Out:
#   STUDENT ID  Student Age  Sex  Graduated high-school type  Scholarship type  \
# 0   STUDENT1            2    2                           3                 3
# 1   STUDENT2            2    2                           3                 3
# 2   STUDENT3            2    2                           2                 3
# 3   STUDENT4            1    1                           1                 3
# 4   STUDENT5            2    2                           1                 3
#
#    Additional work  Regular artistic or sports activity  \
# 0                1                                    2
# 1                1                                    2
# 2                2                                    2
# 3                1                                    2
# 4                2                                    2
#
#    Do you have a partner  Total salary if available  \
# 0                      2                          1
# 1                      2                          1
# 2                      2                          2
# 3                      1                          2
# 4                      1                          3
#
#    Transportation to the university  ...  Preparation to midterm exams 1  \
# 0                                 1  ...                               1
# 1                                 1  ...                               1
# 2                                 4  ...                               1
# 3                                 1  ...                               1
# 4                                 1  ...                               2
#
#    Preparation to midterm exams 2  Taking notes in classes  \
# 0                               1                        3
# 1                               1                        3
# 2                               1                        2
# 3                               2                        3
# 4                               1                        2
#
#    Listening in classes  \
# 0                     2
# 1                     2
# 2                     2
# 3                     2
# 4                     2
#
#    Discussion improves my interest and success in the course  Flip-classroom  \
# 0                                                  1                       2
# 1                                                  3                       2
# 2                                                  1                       1
# 3                                                  2                       1
# 4                                                  2                       1
#
#    Cumulative grade point average in the last semester (/4.00)  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    Expected Cumulative grade point average in the graduation (/4.00)  \
# 0                                                  1
# 1                                                  3
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    COURSE ID  GRADE
# 0          1      1
# 1          1      1
# 2          1      1
# 3          1      1
# 4          1      1
#
# [5 rows x 33 columns]

# %%
df = pd.DataFrame(data)

# %%
# Get and print the column names
column_names = df.columns
print(column_names)
# Out:
# Index(['STUDENT ID', 'Student Age', 'Sex', 'Graduated high-school type',
#        'Scholarship type', 'Additional work',
#        'Regular artistic or sports activity', 'Do you have a partner',
#        'Total salary if available', 'Transportation to the university',
#        'Accommodation type in Cyprus', 'Mother’s education',
#        'Father’s education ', 'Number of sisters/brothers', 'Parental status',
#        'Mother’s occupation', 'Father’s occupation', 'Weekly study hours',
#        'Reading frequency', 'Reading frequency.1',
#        'Attendance to the seminars/conferences related to the department',
#        'Impact of your projects/activities on your success',
#        'Attendance to classes', 'Preparation to midterm exams 1',
#        'Preparation to midterm exams 2', 'Taking notes in classes',
#        'Listening in classes',
#        'Discussion improves my interest and success in the course',
#        'Flip-classroom',
#        'Cumulative grade point average in the last semester (/4.00)',
#        'Expected Cumulative grade point average in the graduation (/4.00)',
#        'COURSE ID', 'GRADE'],
#       dtype='object')

# %%
# Create a new DataFrame with renamed columns
df_renamed = df.rename(columns={'STUDENT ID': 'ID', 'Student Age': 'Age', 
                                'Graduated high-school type': 'high-school type', 
                                'Regular artistic or sports activity': 'activity type',
                               'Do you have a partner': 'existing partner',
                               'Total salary if available': 'Total salary',
                               'Transportation to the university': 'Transportation type',
                               'Accommodation type in Cyprus': 'Accommodation type',
                               'Mother’s education': 'Moms education',
                               'Father’s education ': 'Dads education',
                               'Number of sisters/brothers': 'Siblings amount',
                               'Mother’s occupation': 'Moms job', 'Father’s occupation': 'Dads job',
                               'Reading frequency.1': 'Scientific reading-f', 'Reading frequency': 'Reading-f',
                               'Attendance to the seminars/conferences related to the department': 'Seminar attendance',
                               'Impact of your projects/activities on your success': 'Projects impact on success',
                               'Attendance to classes': 'Class attendance', 'Preparation to midterm exams 1': 'Midterm 1 preparation',
                               'Preparation to midterm exams 2': 'Midterm 2 preparation', 'Taking notes in classes': 'Note taking',
                               'Discussion improves my interest and success in the course': 'Disscusion increases success',
                               'Cumulative grade point average in the last semester (/4.00)': 'Last semester grade point average',
                               'Expected Cumulative grade point average in the graduation (/4.00)': 'Expected grade point average'})
df_renamed.head(5)
# Out:
#          ID  Age  Sex  high-school type  Scholarship type  Additional work  \
# 0  STUDENT1    2    2                 3                 3                1
# 1  STUDENT2    2    2                 3                 3                1
# 2  STUDENT3    2    2                 2                 3                2
# 3  STUDENT4    1    1                 1                 3                1
# 4  STUDENT5    2    2                 1                 3                2
#
#    activity type  existing partner  Total salary  Transportation type  ...  \
# 0              2                 2             1                    1  ...
# 1              2                 2             1                    1  ...
# 2              2                 2             2                    4  ...
# 3              2                 1             2                    1  ...
# 4              2                 1             3                    1  ...
#
#    Midterm 1 preparation  Midterm 2 preparation  Note taking  \
# 0                      1                      1            3
# 1                      1                      1            3
# 2                      1                      1            2
# 3                      1                      2            3
# 4                      2                      1            2
#
#    Listening in classes  Disscusion increases success  Flip-classroom  \
# 0                     2                             1               2
# 1                     2                             3               2
# 2                     2                             1               1
# 3                     2                             2               1
# 4                     2                             2               1
#
#    Last semester grade point average  Expected grade point average  COURSE ID  \
# 0                                  1                             1          1
# 1                                  2                             3          1
# 2                                  2                             2          1
# 3                                  3                             2          1
# 4                                  2                             2          1
#
#    GRADE
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
# [5 rows x 33 columns]

# %%
df_renamed.shape
# Out:
# (145, 33)

# %%
df_renamed.describe()
# Out:
#               Age         Sex  high-school type  Scholarship type  \
# count  145.000000  145.000000        145.000000        145.000000
# mean     1.620690    1.600000          1.944828          3.572414
# std      0.613154    0.491596          0.537216          0.805750
# min      1.000000    1.000000          1.000000          1.000000
# 25%      1.000000    1.000000          2.000000          3.000000
# 50%      2.000000    2.000000          2.000000          3.000000
# 75%      2.000000    2.000000          2.000000          4.000000
# max      3.000000    2.000000          3.000000          5.000000
#
#        Additional work  activity type  existing partner  Total salary  \
# count       145.000000     145.000000        145.000000    145.000000
# mean          1.662069       1.600000          1.579310      1.627586
# std           0.474644       0.491596          0.495381      1.020245
# min           1.000000       1.000000          1.000000      1.000000
# 25%           1.000000       1.000000          1.000000      1.000000
# 50%           2.000000       2.000000          2.000000      1.000000
# 75%           2.000000       2.000000          2.000000      2.000000
# max           2.000000       2.000000          2.000000      5.000000
#
#        Transportation type  Accommodation type  ...  Midterm 1 preparation  \
# count           145.000000          145.000000  ...             145.000000
# mean              1.620690            1.731034  ...               1.337931
# std               1.061112            0.783999  ...               0.614870
# min               1.000000            1.000000  ...               1.000000
# 25%               1.000000            1.000000  ...               1.000000
# 50%               1.000000            2.000000  ...               1.000000
# 75%               2.000000            2.000000  ...               2.000000
# max               4.000000            4.000000  ...               3.000000
#
#        Midterm 2 preparation  Note taking  Listening in classes  \
# count             145.000000   145.000000            145.000000
# mean                1.165517     2.544828              2.055172
# std                 0.408483     0.564940              0.674736
# min                 1.000000     1.000000              1.000000
# 25%                 1.000000     2.000000              2.000000
# 50%                 1.000000     3.000000              2.000000
# 75%                 1.000000     3.000000              3.000000
# max                 3.000000     3.000000              3.000000
#
#        Disscusion increases success  Flip-classroom  \
# count                    145.000000      145.000000
# mean                       2.393103        1.806897
# std                        0.604343        0.810492
# min                        1.000000        1.000000
# 25%                        2.000000        1.000000
# 50%                        2.000000        2.000000
# 75%                        3.000000        2.000000
# max                        3.000000        3.000000
#
#        Last semester grade point average  Expected grade point average  \
# count                         145.000000                    145.000000
# mean                            3.124138                      2.724138
# std                             1.301083                      0.916536
# min                             1.000000                      1.000000
# 25%                             2.000000                      2.000000
# 50%                             3.000000                      3.000000
# 75%                             4.000000                      3.000000
# max                             5.000000                      4.000000
#
#         COURSE ID       GRADE
# count  145.000000  145.000000
# mean     4.131034    3.227586
# std      3.260145    2.197678
# min      1.000000    0.000000
# 25%      1.000000    1.000000
# 50%      3.000000    3.000000
# 75%      7.000000    5.000000
# max      9.000000    7.000000
#
# [8 rows x 32 columns]

# %%
df_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 145 non-null    object
#  1   Age                                145 non-null    int64
#  2   Sex                                145 non-null    int64
#  3   high-school type                   145 non-null    int64
#  4   Scholarship type                   145 non-null    int64
#  5   Additional work                    145 non-null    int64
#  6   activity type                      145 non-null    int64
#  7   existing partner                   145 non-null    int64
#  8   Total salary                       145 non-null    int64
#  9   Transportation type                145 non-null    int64
#  10  Accommodation type                 145 non-null    int64
#  11  Moms education                     145 non-null    int64
#  12  Dads education                     145 non-null    int64
#  13  Siblings amount                    145 non-null    int64
#  14  Parental status                    145 non-null    int64
#  15  Moms job                           145 non-null    int64
#  16  Dads job                           145 non-null    int64
#  17  Weekly study hours                 145 non-null    int64
#  18  Reading-f                          145 non-null    int64
#  19  Scientific reading-f               145 non-null    int64
#  20  Seminar attendance                 145 non-null    int64
#  21  Projects impact on success         145 non-null    int64
#  22  Class attendance                   145 non-null    int64
#  23  Midterm 1 preparation              145 non-null    int64
#  24  Midterm 2 preparation              145 non-null    int64
#  25  Note taking                        145 non-null    int64
#  26  Listening in classes               145 non-null    int64
#  27  Disscusion increases success       145 non-null    int64
#  28  Flip-classroom                     145 non-null    int64
#  29  Last semester grade point average  145 non-null    int64
#  30  Expected grade point average       145 non-null    int64
#  31  COURSE ID                          145 non-null    int64
#  32  GRADE                              145 non-null    int64
# dtypes: int64(32), object(1)
# memory usage: 37.5+ KB

# %%
df_renamed.isna().sum()
# Out:
# ID                                   0
# Age                                  0
# Sex                                  0
# high-school type                     0
# Scholarship type                     0
# Additional work                      0
# activity type                        0
# existing partner                     0
# Total salary                         0
# Transportation type                  0
# Accommodation type                   0
# Moms education                       0
# Dads education                       0
# Siblings amount                      0
# Parental status                      0
# Moms job                             0
# Dads job                             0
# Weekly study hours                   0
# Reading-f                            0
# Scientific reading-f                 0
# Seminar attendance                   0
# Projects impact on success           0
# Class attendance                     0
# Midterm 1 preparation                0
# Midterm 2 preparation                0
# Note taking                          0
# Listening in classes                 0
# Disscusion increases success         0
# Flip-classroom                       0
# Last semester grade point average    0
# Expected grade point average         0
# COURSE ID                            0
# GRADE                                0
# dtype: int64

# %% [markdown]
# ## 2. Visualize relationships / plot the data

# %%
fig, ax = plt.subplots(figsize=(10,10))

correlation_matrix = df_renamed.corr()

sns.heatmap(correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Get and print the column names
column_names = df_renamed.columns
print(column_names)
# Out:
# Index(['ID', 'Age', 'Sex', 'high-school type', 'Scholarship type',
#        'Additional work', 'activity type', 'existing partner', 'Total salary',
#        'Transportation type', 'Accommodation type', 'Moms education',
#        'Dads education', 'Siblings amount', 'Parental status', 'Moms job',
#        'Dads job', 'Weekly study hours', 'Reading-f', 'Scientific reading-f',
#        'Seminar attendance', 'Projects impact on success', 'Class attendance',
#        'Midterm 1 preparation', 'Midterm 2 preparation', 'Note taking',
#        'Listening in classes', 'Disscusion increases success',
#        'Flip-classroom', 'Last semester grade point average',
#        'Expected grade point average', 'COURSE ID', 'GRADE'],
#       dtype='object')

# %%
tempData = df_renamed

selected_columns = ['ID', 'Age', 'Sex', 'high-school type', 'Scholarship type',
       'Additional work', 'activity type', 'existing partner', 'Total salary', 'GRADE']

subset_tempData = tempData[selected_columns]
# Customize the figure size
plt.figure(figsize=(10, 8))

sns.heatmap(subset_tempData.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
tempData = df_renamed

selected_columns = ['Transportation type', 'Accommodation type', 'Moms education',
       'Dads education', 'Siblings amount', 'Parental status', 'Moms job',
       'Dads job', 'GRADE']

subset_tempData = tempData[selected_columns]
# Customize the figure size
plt.figure(figsize=(10, 8))

sns.heatmap(subset_tempData.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
tempData = df_renamed

selected_columns = ['Weekly study hours', 'Reading-f', 'Scientific reading-f',
       'Seminar attendance', 'Projects impact on success', 'Class attendance',
       'Midterm 1 preparation', 'Midterm 2 preparation', 'GRADE']

subset_tempData = tempData[selected_columns]
# Customize the figure size
plt.figure(figsize=(10, 8))

sns.heatmap(subset_tempData.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
tempData = df_renamed

selected_columns = ['Note taking',
       'Listening in classes', 'Disscusion increases success',
       'Flip-classroom', 'Last semester grade point average',
       'Expected grade point average', 'COURSE ID', 'GRADE']

subset_tempData = tempData[selected_columns]
# Customize the figure size
plt.figure(figsize=(10, 8))

sns.heatmap(subset_tempData.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
# Histogram
# %matplotlib inline
df_renamed.hist(bins=50, figsize=(25,25))
plt.show()

# %%
from sklearn import tree
tree_clf = tree.DecisionTreeClassifier(criterion='gini', random_state=42, max_depth=4)
decision_tree = tree_clf.fit(data[['Age','Sex', 'Chest pain','Blood pressure','Cholestoral','Diabetes','Max heart rate','Exercice induced angina','Number of vessels','Other observations']], data['Risk of heart attack'])
plt.figure(figsize=(14,6)) 
tree.plot_tree(decision_tree, feature_names=['Age','Sex','Chest pain','Blood pressure','Cholestoral','Diabetes','Max heart rate','Exercice induced angina','Number of vessels','Other observations'],fontsize=7)
plt.show()

# %% [markdown]
# ## 3. Build ML models

# %% [markdown]
# ### Prepare the data
